# %%
###Take folder directory as input, aggregate all data together using filename as value in frame column


#imports
import numpy as np
import pandas as pd
import os

# %%
#read in file


#folder_path = './processed_day1_test1/'

#folder_path = './processed_day1_test2/'

#folder_path = './processed_day1_test3/'

folder_path = './processed_image-set/'

# %%
files = [f for f in os.listdir(folder_path)]# if os.path.isfile(f)]

merged = []

for f in files:
    filename, ext = os.path.splitext(f)
    if ext == '.csv':
        read = pd.read_csv(os.path.join(folder_path,f))
        read['frame'] = int(filename[0:3])
        merged.append(read)

result = pd.concat(merged)

# %%
#add index column as the frame col probably
result.set_index('frame',inplace=True)
result.sort_index(inplace=True)

result
# Out:
#        face   confidence   gaze_0_x   gaze_0_y   gaze_0_z   gaze_1_x  \
# frame
# 1         0        0.975   0.147156   0.530385  -0.834887  -0.013528
# 1         1        0.875   0.206391   0.493255  -0.845046   0.047888
# 1         2        0.975   0.411190   0.524658  -0.745424   0.258350
# 1         3        0.000   0.321795   0.544525  -0.774558   0.176493
# 2         0        0.875   0.023015   0.337037  -0.941210  -0.144893
# ...     ...          ...        ...        ...        ...        ...
# 212       1        0.925   0.137750   0.449515  -0.882588  -0.022957
# 212       2        0.875   0.081305   0.492686  -0.866401  -0.080588
# 212       3        0.475  -0.237656   0.441008  -0.865466  -0.374776
# 213       0        0.975   0.108946   0.473483  -0.874039  -0.059754
# 213       1        0.925   0.053266   0.388186  -0.920040  -0.113623
#
#         gaze_1_y   gaze_1_z   gaze_angle_x   gaze_angle_y  ...    Z_58  \
# frame                                                      ...
# 1       0.515166  -0.856984          0.079          0.554  ...  2035.1
# 1       0.502498  -0.863251          0.148          0.528  ...  2007.7
# 1       0.537575  -0.802663          0.408          0.601  ...  1729.7
# 1       0.549575  -0.816589          0.303          0.602  ...  2552.8
# 2       0.346467  -0.926804         -0.065          0.351  ...   929.8
# ...          ...        ...            ...            ...  ...     ...
# 212     0.447877  -0.893800          0.065          0.468  ...  1737.9
# 212     0.476221  -0.875625          0.000          0.508  ...  1782.7
# 212     0.403684  -0.834615         -0.346          0.461  ...  2189.8
# 213     0.479515  -0.875497          0.028          0.499  ...  1294.4
# 213     0.379126  -0.918343         -0.033          0.395  ...  1499.9
#
#          Z_59    Z_60    Z_61    Z_62    Z_63    Z_64    Z_65    Z_66    Z_67
# frame
# 1      2037.5  2044.0  2034.6  2036.1  2040.1  2059.7  2041.2  2037.1  2035.8
# 1      2012.0  2019.9  2008.8  2009.1  2011.8  2028.8  2011.9  2009.1  2009.0
# 1      1730.7  1735.3  1729.3  1731.5  1735.9  1755.7  1736.4  1731.9  1729.9
# 1      2558.4  2567.4  2552.9  2552.5  2554.9  2572.5  2555.9  2553.5  2554.1
# 2       933.4   940.6   931.4   932.1   934.8   950.8   934.0   931.0   930.6
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 212    1747.7  1758.0  1737.2  1733.8  1732.2  1742.6  1733.1  1734.8  1738.5
# 212    1788.2  1796.3  1781.9  1781.1  1782.4  1796.6  1783.0  1781.6  1782.7
# 212    2199.3  2209.7  2188.9  2185.6  2184.2  2193.8  2185.3  2186.7  2190.4
# 213    1300.4  1309.0  1295.0  1293.9  1295.0  1309.3  1295.8  1294.7  1295.8
# 213    1503.6  1511.4  1502.1  1502.9  1506.3  1524.4  1506.0  1502.6  1501.9
#
# [487 rows x 636 columns]

# %%
result.to_csv(folder_path+'openface_features.csv')
